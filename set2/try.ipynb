# %%
b'dandjan'+b'asada'
# Out:
# b'dandjanasada'

# %%
from set1.c7 import AES
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from set1.c7 import AES
#
# ModuleNotFoundError: No module named 'set1'
